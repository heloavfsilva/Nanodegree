# %% [markdown]
# # Project: Investigate Movie Dataset
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# During this article we will investigate the Movie dataset selected for analysis.
# At the end of this section we will try to answer the following questions:
# 1. What is the correlation between the genres and the movies popularity mean?
# 2. What are the features of the most popular movies?

# %%
# import the necessary dependencies to perform the gathering, assessing, cleaning and plotting the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# During the next cells we will load the data, check for duplicates and trim it,
# in order to be ready for analyze.
#
#
# ### General Properties

# %%
# Load the data and print the data to analyze the information
df_movie = pd.read_csv('tmdb-movies.csv')
df_movie.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# print the information of the dataset in order to look for missing values and duplicates
df_movie.info()
print('Count of duplicated: ' + str(df_movie.duplicated().sum()))
print('Columns and rows: ' + str(df_movie.shape))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %% [markdown]
# ### Remove Missing Data

# %%
#  clean the missing values and print again 
df_movie.dropna(inplace=True)
df_movie.info()
print('Count of duplicated: ' + str(df_movie.duplicated().sum()))
print('Columns and rows: ' + str(df_movie.shape))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 21 columns):
# id                      1992 non-null int64
# imdb_id                 1992 non-null object
# popularity              1992 non-null float64
# budget                  1992 non-null int64
# revenue                 1992 non-null int64
# original_title          1992 non-null object
# cast                    1992 non-null object
# homepage                1992 non-null object
# director                1992 non-null object
# tagline                 1992 non-null object
# keywords                1992 non-null object
# overview                1992 non-null object
# runtime                 1992 non-null int64
# genres                  1992 non-null object
# production_companies    1992 non-null object
# release_date            1992 non-null object
# vote_count              1992 non-null int64
# vote_average            1992 non-null float64
# ...

# %%
# Generate a new dataframe to split the column genres
new_df = pd.DataFrame(df_movie.genres.str.split('|').tolist(), index=df_movie.id).stack()
new_df = new_df.reset_index([0, 'id'])

new_df.columns = ['id', 'genres_split']
new_df.head()
# Out:
#        id     genres_split
# 0  135397           Action
# 1  135397        Adventure
# 2  135397  Science Fiction
# 3  135397         Thriller
# 4   76341           Action

# %%
# Combine the genres dataframe with the Movie dataframe using an inner join relation
# Drop the previous column
df_combined = pd.merge(new_df, df_movie, on='id', how='inner')
df_combined.drop(columns="genres", inplace=True)
df_combined.head()
# Out:
#        id     genres_split    imdb_id  popularity     budget     revenue  \
# 0  135397           Action  tt0369610   32.985763  150000000  1513528810
# 1  135397        Adventure  tt0369610   32.985763  150000000  1513528810
# 2  135397  Science Fiction  tt0369610   32.985763  150000000  1513528810
# 3  135397         Thriller  tt0369610   32.985763  150000000  1513528810
# 4   76341           Action  tt1392190   28.419936  150000000   378436354
#
#        original_title                                               cast  \
# 0      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 2      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 3      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 4  Mad Max: Fury Road  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director      ...       \
# ...

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
# ### 1. What is the correlation between the genres and the movies popularity mean?

# %%
# Print the Popularity data to explore it
df_combined['popularity'].describe()
# Out:
# count    5123.000000
# mean        1.466109
# std         2.092849
# min         0.000620
# 25%         0.423160
# 50%         0.847636
# 75%         1.752987
# max        32.985763
# Name: popularity, dtype: float64

# %%
# Grouping the popularity by genres_split and calculate the mean 
# Plotting the data we can notice that the genres Adventure, Fantasy and Science Fiction has the highest Popularity Rating 
popularity_values=df_combined.groupby(['genres_split'])['popularity'].mean().plot(kind='bar')
plt.title('Correlation between Genres and Movies Popularity')
plt.xlabel('Genres Category')
plt.ylabel('Popularity Rating Mean');

# %% [markdown]
# ### 2. What are the features of the most popular movies?

# %%
# Checking for most popular movies data
df_top = df_combined.query('genres_split in ["Adventure","Fantasy","Science Fiction"]')
df_top.head()
# Out:
#        id     genres_split    imdb_id  popularity     budget     revenue  \
# 1  135397        Adventure  tt0369610   32.985763  150000000  1513528810
# 2  135397  Science Fiction  tt0369610   32.985763  150000000  1513528810
# 5   76341        Adventure  tt1392190   28.419936  150000000   378436354
# 6   76341  Science Fiction  tt1392190   28.419936  150000000   378436354
# 8  262500        Adventure  tt2908446   13.112507  110000000   295238201
#
#        original_title                                               cast  \
# 1      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 2      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 5  Mad Max: Fury Road  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 6  Mad Max: Fury Road  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 8           Insurgent  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# ...

# %%
# Plotting the information of the top movie genres, was not possible to notice any positive correlation
pd.plotting.scatter_matrix(df_top, alpha=0.2, figsize=(10, 10), diagonal='kde');

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# Finally, based on the dataset information, was posible to address the the question regarding the correlation between Genres of the movies with the Popularity rating.
# I had to perform a minor adjustment in the dataset, I splited the Genres values in multiples lines
# next, I find the top genres population was "Adventure","Fantasy", "Science Fiction"
# therefor I filtered these itens to analyze if there were positive correlation between the other attributes.
# and to do this analysis I have not found limitations with the data.
# There were missing values, in the wraggling phase I removed to increase data accuracy.
# however taking the top movies no other feature has strong positive correlation.
